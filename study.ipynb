# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusCesarSena/Assorted_codes/blob/main/study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
caminho_arquivo = '/content/drive/MyDrive/atracoes.csv'

# %%
try:
  dataframe_atracoes = pd.read_csv(caminho_arquivo)
  df= dataframe_atracoes.copy()
except pd.errors.ParserError:
  print("Erro ao ler o arquivo CSV.Verificar formato do arquivo")

# %%
print(f"A quantidade de linhas e colunas da tabela, respectivamente é: {df.shape}\n")

df.info()
# Out:
# A quantidade de linhas e colunas da tabela, respectivamente é: (39, 5)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nome_atracao        39 non-null     object
#  1   quantidade_reviews  39 non-null     object
#  2   preco_atracao       39 non-null     object
#  3   Tipo_de_Atracao     39 non-null     object
#  4   nota_da_atracao     39 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 1.6+ KB

# %%
df.head()
# Out:
#                                      nome_atracao quantidade_reviews  \
# 0  Santiago Bernabéu Stadium & Real Madrid Museum  (1283 avaliações)
# 1                Toledo Full-day Tour from Madrid   (693 avaliações)
# 2                            Prado Museum Tickets   (389 avaliações)
# 3                       Hop-on, Hop-off City Tour   (999 avaliações)
# 4                    Warner Park Madrid Admission   (956 avaliações)
#
#   preco_atracao                                    Tipo_de_Atracao  \
# 0     R$ 135,15  A ticket to see trophies and artefacts at the ...
# 1     R$ 145,96  A trip to the UNESCO-listed Old Town with free...
# 2      R$ 94,60  A stunning display of art by the great Europea...
# 3     R$ 135,15  A sightseeing tour through Madrid's streets an...
# 4     R$ 161,64  A skip-the-line ticket to Warner Park Madrid f...
#
#    nota_da_atracao
# 0              4.2
# 1              4.5
# 2              3.6
# 3              4.5
# 4              4.6

# %%
round(df.describe(),1)
# Out:
#        nota_da_atracao
# count             39.0
# mean               4.5
# std                0.3
# min                3.6
# 25%                4.3
# 50%                4.5
# 75%                4.7
# max                4.9

# %%
display(df)
# Out:
#                                          nome_atracao quantidade_reviews  \
# 0      Santiago Bernabéu Stadium & Real Madrid Museum  (1283 avaliações)
# 1                    Toledo Full-day Tour from Madrid   (693 avaliações)
# 2                                Prado Museum Tickets   (389 avaliações)
# 3                           Hop-on, Hop-off City Tour   (999 avaliações)
# 4                        Warner Park Madrid Admission   (956 avaliações)
# 5        Prado, Thyssen-Bornemisza & Reina Sofía Pass   (691 avaliações)
# 6            Admission to a Traditional Flamenco Show   (441 avaliações)
# 7                        Reina Sofía Museum Admission   (552 avaliações)
# 8                  Madrid Museum of Illusions Tickets   (542 avaliações)
# 9            Parque Warner Beach Skip-the-line Ticket    (71 avaliações)
# 10  Madrid Essential: Historic Center, Plaza Mayor...   (105 avaliações)
# 11         Ticket for Flamenco Show at Madrid Theater    (74 avaliações)
# ...
